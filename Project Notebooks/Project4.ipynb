# %% [markdown]
# # Web Scraping for Indeed.com & Predicting Salaries

# %% [markdown]
# In this project, we will practice two major skills: collecting data by scraping a website and then building a binary predictor with Logistic Regression.
#
# We are going to collect salary information on data science jobs in a variety of markets. Then using the location, title and summary of the job we will attempt to predict the salary of the job. For job posting sites, this would be extraordinarily useful. While most listings DO NOT come with salary information (as you will see in this exercise), being to able extrapolate or predict the expected salaries from other listings can help guide negotiations.
#
# Normally, we could use regression for this task; however, we will convert this problem into classification and use Logistic Regression.
#
# - Question: Why would we want this to be a classification problem?
# - Answer: While more precision may be better, there is a fair amount of natural variance in job salaries - predicting a range be may be useful.
#
# Therefore, the first part of the assignment will be focused on scraping Indeed.com. In the second, we'll focus on using listings with salary information to build a model and predict additional salaries.

# %% [markdown]
# ### Scraping job listings from Indeed.com

# %% [markdown]
# We will be scraping job listings from Indeed.com using BeautifulSoup. Luckily, Indeed.com is a simple text page where we can easily find relevant entries.
#
# First, look at the source of an Indeed.com page: (http://www.indeed.com/jobs?q=data+scientist+%2420%2C000&l=New+York&start=10")
#
# Notice, each job listing is underneath a `div` tag with a class name of `result`. We can use BeautifulSoup to extract those.

# %% [markdown]
# #### Setup a request (using `requests`) to the URL below. Use BeautifulSoup to parse the page and extract all results (HINT: Look for div tags with class name result)

# %%
URL = "http://www.indeed.com/jobs?q=data+scientist+%2420%2C000&l=New+York&start=10"

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import requests
import bs4
from bs4 import BeautifulSoup
from sklearn.linear_model import LogisticRegression, LogisticRegressionCV
from sklearn.cross_validation import train_test_split, cross_val_score
from sklearn.metrics import confusion_matrix
from sklearn import metrics
import statsmodels.api as sm
# %matplotlib inline

# %% [markdown]
# ### Learning to use Beutifulsoup to extract information out of indeed.com

# %% [raw]
# r = requests.get(URL)
# soup = BeautifulSoup(r.content)
# results = soup.find_all("div", {'class' : ' row result'})
# print results[0].find('span', {'class':'company'}).get_text().strip()
# print results[0].find('a', {'class':'turnstileLink'}).get_text().strip()
# print results[0].find('span', {'class':'location'}).get_text().strip()

# %% [raw]
# These links helped me determine the behavior of the website in order loop through several results (Pages, cities and salary)
#
# http://www.indeed.com/jobs?q=data+scientist+%2450%2C000&l=New+York%2C+NY
# http://www.indeed.com/jobs?q=data+scientist+%2450%2C000&l=San+Francisco%2C+CA
# http://www.indeed.com/jobs?q=data+scientist+%2470%2C000&l=San+Francisco%2C+CA
# http://www.indeed.com/jobs?q=data+scientist+%24100%2C000&l=San+Francisco%2C+CA
# http://www.indeed.com/jobs?q=data+scientist+%2450%2C000+-+%2490%2C000&l=San+Francisco%2C+CA
# http://www.indeed.com/jobs?q=data+scientist+%2450%2C000+-+%2490%2C000&l=San+Francisco%2C+CA&start=10
# http://www.indeed.com/jobs?q=data+scientist+%2450%2C000+-+%2490%2C000&l=San+Francisco%2C+CA&start=20

# %% [markdown]
# Let's look at one result more closely. A single `result` looks like
#
# ```
# <div class=" row result" data-jk="2480d203f7e97210" data-tn-component="organicJob" id="p_2480d203f7e97210" itemscope="" itemtype="http://schema.org/JobPosting">
# <h2 class="jobtitle" id="jl_2480d203f7e97210">
# <a class="turnstileLink" data-tn-element="jobTitle" onmousedown="return rclk(this,jobmap[0],1);" rel="nofollow" target="_blank" title="AVP/Quantitative Analyst">AVP/Quantitative Analyst</a>
# </h2>
# <span class="company" itemprop="hiringOrganization" itemtype="http://schema.org/Organization">
# <span itemprop="name">
# <a href="/cmp/Alliancebernstein?from=SERP&amp;campaignid=serp-linkcompanyname&amp;fromjk=2480d203f7e97210&amp;jcid=b374f2a780e04789" target="_blank">
#     AllianceBernstein</a></span>
# </span>
# <tr>
# <td class="snip">
# <nobr>$117,500 - $127,500 a year</nobr>
# <div>
# <span class="summary" itemprop="description">
# C onduct quantitative and statistical research as well as portfolio management for various investment portfolios. Collaborate with Quantitative Analysts and</span>
# </div>
# </div>
# </td>
# </tr>
# </table>
# </div>
# ```
#
# While this has some more verbose elements removed, we can see that there is some structure to the above:
# - The salary is available in a `nobr` element inside of a `td` element with `class='snip`.
# - The title of a job is in a link with class set to `jobtitle` and a `data-tn-element="jobTitle`.
# - The location is set in a `span` with `class='location'`.
# - The company is set in a `span` with `class='company'`.

# %% [markdown]
# #### Obtaining results for low salary range

# %%
base_url = "http://www.indeed.com/jobs?q=data+scientist+%2430%2C000+-+%2480%2C000&l="

start_from = '&start='    # start page number


df = pd.DataFrame()   # create a new data frame

for city in set(['New+York%2C+NY', 'Chicago%2C+IL', 'San+Francisco%2C+CA', 
                                        'Austin%2C+TX', 'Boston%2C+MA']):
    cityString = city
    for page in range(1,21): # Page from 1 to 20 
        page = (page-1) * 10  #Page Equation
        url = "%s%s%s%d" % (base_url, cityString , start_from, page) # get full url 
        r = requests.get(url) #
        soup = BeautifulSoup(r.content,'lxml') 

        results = soup.find_all("div", {'class' : ' row result'}) # we're interested in each row
    
        # trying to get each specific job information (such as company name, job title, ...)
        for i in range(len(results)): 
            comp_name = results[i].find('span', {'class':'company'}).get_text().strip()
            job_title = results[i].find('a', {'class':'turnstileLink'}).get_text().strip()
            location = city
            summary = results[i].find('span',{'class':'summary'}).get_text().strip()
            

    
            # Add job info to our data frame
            df = df.append({'Company Name': comp_name, 'Job Title': job_title, 
                        'Location': location, 'Summary': summary, 
                            'Salary Index': int(0)}, ignore_index=True)

df
# Out:
#                                Company Name  \
# 0         Alambic Investment Management, LP
# 1                                    Twitch
# 2                                     Dolby
# 3    University of California San Francisco
# 4    University of California San Francisco
# 5                       The Nielsen Company
# 6                                    Natera
# 7                                  Ancestry
# 8                                  Ancestry
# 9                     DiscoveRx Corporation
# 10                                PR Hacker
# 11               Marcus & Millichap Company
# 12                                Genentech
# 13        University of California Berkeley
# 14   University of California San Francisco
# 15                            Fanatics Inc.
# 16                           Illumina, Inc.
# 17                                 Samba TV
# 18                        Realogy Corporate
# 19                                Genentech
# 20          SEIU United Health Care Workers
# 21   University of California San Francisco
# 22   University of California San Francisco
# 23                                   Trulia
# 24                        Kaiser Permanente
# 25         Colliers International | Oakland
# 26                                     UCSF
# 27                            Payette Group
# 28                              AncestryDNA
# 29                                     Nuna
# ..                                      ...
# 790           University of Texas at Austin
# 791                   Myriad Genetics, Inc.
# 792                                  Natera
# 793                        Magic Leap, Inc.
# 794           University of Texas at Austin
# 795                   Myriad Genetics, Inc.
# 796                                  Natera
# 797                        Magic Leap, Inc.
# 798           University of Texas at Austin
# 799                   Myriad Genetics, Inc.
# 800                                  Natera
# 801                        Magic Leap, Inc.
# 802           University of Texas at Austin
# 803                   Myriad Genetics, Inc.
# 804                                  Natera
# 805                        Magic Leap, Inc.
# 806           University of Texas at Austin
# 807                   Myriad Genetics, Inc.
# 808                                  Natera
# 809                        Magic Leap, Inc.
# 810           University of Texas at Austin
# 811                   Myriad Genetics, Inc.
# 812                                  Natera
# 813                        Magic Leap, Inc.
# 814           University of Texas at Austin
# 815                   Myriad Genetics, Inc.
# 816                                  Natera
# 817                        Magic Leap, Inc.
# 818           University of Texas at Austin
# 819                   Myriad Genetics, Inc.
#
#                                              Job Title             Location  \
# 0                            Data Scientist / Engineer  San+Francisco%2C+CA
# 1                                       Data Scientist  San+Francisco%2C+CA
# 2    [Summer Session] Social Media and Data Analysi...  San+Francisco%2C+CA
# 3                                Research Data Analyst  San+Francisco%2C+CA
# 4                                     Research Analyst  San+Francisco%2C+CA
# 5               Research Analyst/ Sr. Research Analyst  San+Francisco%2C+CA
# 6                                       Data Scientist  San+Francisco%2C+CA
# 7                                Senior Data Scientist  San+Francisco%2C+CA
# 8                             Scientific Data Wrangler  San+Francisco%2C+CA
# 9                           Scientist/Senior Scientist  San+Francisco%2C+CA
# 10                                      Data Scientist  San+Francisco%2C+CA
# 11                             Market Research Analyst  San+Francisco%2C+CA
# 12       Intern - Statistical Programming and Analysis  San+Francisco%2C+CA
# 13   Associate Director of Data Analysis, Haas Scho...  San+Francisco%2C+CA
# 14                            Research Finance Analyst  San+Francisco%2C+CA
# 15                                      Data Scientist  San+Francisco%2C+CA
# 16                       Research Associate- Scientist  San+Francisco%2C+CA
# 17      Research Scientist, Video and Image Processing  San+Francisco%2C+CA
# 18                               Junior Data Scientist  San+Francisco%2C+CA
# 19         Bioinformatics Scientist, Cancer Immunology  San+Francisco%2C+CA
# 20                                    Research Analyst  San+Francisco%2C+CA
# 21                      Financial / Post-award Analyst  San+Francisco%2C+CA
# 22                        Department Financial Analyst  San+Francisco%2C+CA
# 23                                Quantitative Analyst  San+Francisco%2C+CA
# 24                   Research Scientist I Investigator  San+Francisco%2C+CA
# 25                                    Research Analyst  San+Francisco%2C+CA
# 26                                 Postdoctoral Fellow  San+Francisco%2C+CA
# 27                                      Data Scientist  San+Francisco%2C+CA
# 28                               Bioinformatic Analyst  San+Francisco%2C+CA
# 29                      Commercial Health Data Analyst  San+Francisco%2C+CA
# ..                                                 ...                  ...
# 790  Engineering Scientist Associate - Software Def...         Austin%2C+TX
# 791          Temporary Laboratory Technician (Testing)         Austin%2C+TX
# 792  Medical Technologist & Medical Results Coordin...         Austin%2C+TX
# 793                          System Administrator (TX)         Austin%2C+TX
# 794  Engineering Scientist Associate - Software Def...         Austin%2C+TX
# 795          Temporary Laboratory Technician (Testing)         Austin%2C+TX
# 796  Medical Technologist & Medical Results Coordin...         Austin%2C+TX
# 797                          System Administrator (TX)         Austin%2C+TX
# 798  Engineering Scientist Associate - Software Def...         Austin%2C+TX
# 799          Temporary Laboratory Technician (Testing)         Austin%2C+TX
# 800  Medical Technologist & Medical Results Coordin...         Austin%2C+TX
# 801                          System Administrator (TX)         Austin%2C+TX
# 802  Engineering Scientist Associate - Software Def...         Austin%2C+TX
# 803          Temporary Laboratory Technician (Testing)         Austin%2C+TX
# 804  Medical Technologist & Medical Results Coordin...         Austin%2C+TX
# 805                          System Administrator (TX)         Austin%2C+TX
# 806  Engineering Scientist Associate - Software Def...         Austin%2C+TX
# 807          Temporary Laboratory Technician (Testing)         Austin%2C+TX
# 808  Medical Technologist & Medical Results Coordin...         Austin%2C+TX
# 809                          System Administrator (TX)         Austin%2C+TX
# 810  Engineering Scientist Associate - Software Def...         Austin%2C+TX
# 811          Temporary Laboratory Technician (Testing)         Austin%2C+TX
# 812  Medical Technologist & Medical Results Coordin...         Austin%2C+TX
# 813                          System Administrator (TX)         Austin%2C+TX
# 814  Engineering Scientist Associate - Software Def...         Austin%2C+TX
# 815          Temporary Laboratory Technician (Testing)         Austin%2C+TX
# 816  Medical Technologist & Medical Results Coordin...         Austin%2C+TX
# 817                          System Administrator (TX)         Austin%2C+TX
# 818  Engineering Scientist Associate - Software Def...         Austin%2C+TX
# 819          Temporary Laboratory Technician (Testing)         Austin%2C+TX
#
#      Salary Index                                            Summary
# 0             0.0  We are a small, entrepreneurial San Francisco-...
# 1             0.0  We think of Emmett, the CEO, as Twitch’s origi...
# 2             0.0  Analyze online trends and data. Strong data an...
# 3             0.0  The Research Data Analyst will provide statist...
# 4             0.0  Assisting off-site research assistants with qu...
# 5             0.0  Data Processing Management. Oversee all data p...
# 6             0.0  Natera is seeking a highly motivated Data Scie...
# 7             0.0  Data Mining Product team is looking for an exp...
# 8             0.0  Working with a nimble team of physicians, gene...
# 9             0.0  Scientist/Senior Scientist position currently ...
# 10            0.0  If so, you might make a killer Data Scientist ...
# 11            0.0  Ability to manage data and create statistical ...
# 12            0.0  Data Science, Statistics, Biostatistics, Compu...
# 13            0.0  Experienced in working with a small to med siz...
# 14            0.0  The Department of Obstetrics, Gynecology and R...
# 15            0.0  Ability to use SQL to perform data analysis. A...
# 16            0.0  Strong bioinformatics, data analysis and visua...
# 17            0.0  Solid foundation in computer science, with str...
# 18            0.0  Junior Data Scientist. The Junior Data Scienti...
# 19            0.0  Exceptionally strong communication, data prese...
# 20            0.0  Position Summary : Our Research Department is ...
# 21            0.0  By fostering cross-disciplinary interactions a...
# 22            0.0  Develop data sources; Experience with database...
# 23            0.0  Experience with Big Data tools such as Hive/Pr...
# 24            0.0  Seeks consultation from senior scientists for ...
# 25            0.0  Compile statistical data specific to client or...
# 26            0.0  (2) strong skills in data management of comple...
# 27            0.0  Having tens of thousands of debtors and contac...
# 28            0.0  Working with a nimble team of physicians, gene...
# 29            0.0  Works with consultants, analysts and data scie...
# ..            ...                                                ...
# 790           0.0  Experience with digital data distribution tech...
# 791           0.0  The Lab Technician I reports to a Supervisor, ...
# 792           0.0  Word processing and data management skills req...
# 793           0.0  Performs data backups and data recovery operat...
# 794           0.0  Experience with digital data distribution tech...
# 795           0.0  The Lab Technician I reports to a Supervisor, ...
# 796           0.0  Word processing and data management skills req...
# 797           0.0  Performs data backups and data recovery operat...
# 798           0.0  Experience with digital data distribution tech...
# 799           0.0  The Lab Technician I reports to a Supervisor, ...
# 800           0.0  Word processing and data management skills req...
# 801           0.0  Performs data backups and data recovery operat...
# 802           0.0  Experience with digital data distribution tech...
# 803           0.0  The Lab Technician I reports to a Supervisor, ...
# 804           0.0  Word processing and data management skills req...
# 805           0.0  Performs data backups and data recovery operat...
# 806           0.0  Experience with digital data distribution tech...
# 807           0.0  The Lab Technician I reports to a Supervisor, ...
# 808           0.0  Word processing and data management skills req...
# 809           0.0  Performs data backups and data recovery operat...
# 810           0.0  Experience with digital data distribution tech...
# 811           0.0  The Lab Technician I reports to a Supervisor, ...
# 812           0.0  Word processing and data management skills req...
# 813           0.0  Performs data backups and data recovery operat...
# 814           0.0  Experience with digital data distribution tech...
# 815           0.0  The Lab Technician I reports to a Supervisor, ...
# 816           0.0  Word processing and data management skills req...
# 817           0.0  Performs data backups and data recovery operat...
# 818           0.0  Experience with digital data distribution tech...
# 819           0.0  The Lab Technician I reports to a Supervisor, ...
#
# [820 rows x 5 columns]

# %% [markdown]
# #### Obtaining results for high salary range

# %%
base_url = "http://www.indeed.com/jobs?q=data+scientist+%2480%2C000+-+%2530%2C000&l="

start_from = '&start='    # start page number


df2 = pd.DataFrame()   # create a new data frame

for city in set(['New+York%2C+NY', 'Chicago%2C+IL', 'San+Francisco%2C+CA', 
                                        'Austin%2C+TX', 'Boston%2C+MA']):
    cityString = city
    for page in range(1,21): # Page from 1 to 20 
        page = (page-1) * 10  #Page Equation
        url = "%s%s%s%d" % (base_url, cityString , start_from, page) # get full url 
        r = requests.get(url) #
        soup = BeautifulSoup(r.content,'lxml') 

        results = soup.find_all("div", {'class' : ' row result'}) # we're interested in each row
    
        # trying to get each specific job information (such as company name, job title, ...)
        for i in range(len(results)): 
            comp_name = results[i].find('span', {'class':'company'}).get_text().strip()
            job_title = results[i].find('a', {'class':'turnstileLink'}).get_text().strip()
            location = city
            summary = results[i].find('span',{'class':'summary'}).get_text().strip()
            

    
            # Add job info to our data frame
            df2 = df2.append({'Company Name': comp_name, 'Job Title': job_title, 
                        'Location': location, 'Summary': summary, 
                            'Salary Index': int(1)}, ignore_index=True)

df2
# Out:
#                               Company Name  \
# 0                              MarkMonitor
# 1                                   Docker
# 2                                Glassdoor
# 3                          Thomson Reuters
# 4                           O'Reilly Media
# 5                                  Jawbone
# 6    Lawrence Berkeley National Laboratory
# 7                                Glassdoor
# 8                  Smith Hanley Associates
# 9                           HSF Consulting
# 10                 Smith Hanley Associates
# 11                        Rocket Fuel Inc.
# 12                          Culver Careers
# 13   Lawrence Berkeley National Laboratory
# 14                               Glassdoor
# 15                        Impossible Foods
# 16                           Profusa, Inc.
# 17                              Protingent
# 18                              CyberCraft
# 19                  Aspera, an IBM Company
# 20                               Glassdoor
# 21                                 In-Team
# 22                                  Docker
# 23                               Glassdoor
# 24                                Ecorithm
# 25                                 In-Team
# 26                                  Docker
# 27                                  Docker
# 28                      Jobspring Partners
# 29                                   Talon
# ..                                     ...
# 484                                 Docker
# 485          CCC Information Services Inc.
# 486          University of Texas at Austin
# 487          CCC Information Services Inc.
# 488                                 Docker
# 489          CCC Information Services Inc.
# 490          University of Texas at Austin
# 491          CCC Information Services Inc.
# 492                                 Docker
# 493          CCC Information Services Inc.
# 494          University of Texas at Austin
# 495          CCC Information Services Inc.
# 496                                 Docker
# 497          CCC Information Services Inc.
# 498          University of Texas at Austin
# 499          CCC Information Services Inc.
# 500                                 Docker
# 501          CCC Information Services Inc.
# 502          University of Texas at Austin
# 503          CCC Information Services Inc.
# 504                                 Docker
# 505          CCC Information Services Inc.
# 506          University of Texas at Austin
# 507          CCC Information Services Inc.
# 508                                 Docker
# 509          CCC Information Services Inc.
# 510          University of Texas at Austin
# 511          CCC Information Services Inc.
# 512                                 Docker
# 513          CCC Information Services Inc.
#
#                                              Job Title             Location  \
# 0                                       Data Scientist  San+Francisco%2C+CA
# 1    Senior Manager/Director, Alliances-Strategic D...  San+Francisco%2C+CA
# 2                             Principal Data Scientist  San+Francisco%2C+CA
# 3                                       Data Scientist  San+Francisco%2C+CA
# 4                            Junior Research Scientist  San+Francisco%2C+CA
# 5                                       Data Scientist  San+Francisco%2C+CA
# 6    Atomic and Molecular Dynamics Postdoctoral Fel...  San+Francisco%2C+CA
# 7                Lead Data Scientist, Machine Learning  San+Francisco%2C+CA
# 8                                       Data Scientist  San+Francisco%2C+CA
# 9                                  VP of Data Services  San+Francisco%2C+CA
# 10                               Manager, Data Science  San+Francisco%2C+CA
# 11                             Senior Rocket Scientist  San+Francisco%2C+CA
# 12                                   Account Executive  San+Francisco%2C+CA
# 13                         Project Scientist (Physics)  San+Francisco%2C+CA
# 14            Senior Software Engineer - Data Platform  San+Francisco%2C+CA
# 15     R&D Food Product Development Scientist/Engineer  San+Francisco%2C+CA
# 16                           Sensor Scientist/Engineer  San+Francisco%2C+CA
# 17                               CloudScaling Engineer  San+Francisco%2C+CA
# 18                   Senior Sales Manager (part-time )  San+Francisco%2C+CA
# 19                              Sr. Solutions Engineer  San+Francisco%2C+CA
# 20                      Lead Machine Learning Engineer  San+Francisco%2C+CA
# 21            Lead développeur Ruby | Start-up établie  San+Francisco%2C+CA
# 22       Director, Human Resources/HR Business Partner  San+Francisco%2C+CA
# 23                          Machine Learning Architect  San+Francisco%2C+CA
# 24                             Account Executive/Sales  San+Francisco%2C+CA
# 25      Lead Dev Ruby/DevOps | Visa Pour San Francisco  San+Francisco%2C+CA
# 26        Interaction Designer, UX, and Product Design  San+Francisco%2C+CA
# 27                    Regional Account Executive, West  San+Francisco%2C+CA
# 28                  Software Architect - hands on Java  San+Francisco%2C+CA
# 29                       Full Stack Web Developer - SF  San+Francisco%2C+CA
# ..                                                 ...                  ...
# 484          Regional Account Executive, South Central         Austin%2C+TX
# 485                                     Java Developer         Austin%2C+TX
# 486                                 Research Scientist         Austin%2C+TX
# 487                                   Python Developer         Austin%2C+TX
# 488          Regional Account Executive, South Central         Austin%2C+TX
# 489                                     Java Developer         Austin%2C+TX
# 490                                 Research Scientist         Austin%2C+TX
# 491                                   Python Developer         Austin%2C+TX
# 492          Regional Account Executive, South Central         Austin%2C+TX
# 493                                     Java Developer         Austin%2C+TX
# 494                                 Research Scientist         Austin%2C+TX
# 495                                   Python Developer         Austin%2C+TX
# 496          Regional Account Executive, South Central         Austin%2C+TX
# 497                                     Java Developer         Austin%2C+TX
# 498                                 Research Scientist         Austin%2C+TX
# 499                                   Python Developer         Austin%2C+TX
# 500          Regional Account Executive, South Central         Austin%2C+TX
# 501                                     Java Developer         Austin%2C+TX
# 502                                 Research Scientist         Austin%2C+TX
# 503                                   Python Developer         Austin%2C+TX
# 504          Regional Account Executive, South Central         Austin%2C+TX
# 505                                     Java Developer         Austin%2C+TX
# 506                                 Research Scientist         Austin%2C+TX
# 507                                   Python Developer         Austin%2C+TX
# 508          Regional Account Executive, South Central         Austin%2C+TX
# 509                                     Java Developer         Austin%2C+TX
# 510                                 Research Scientist         Austin%2C+TX
# 511                                   Python Developer         Austin%2C+TX
# 512          Regional Account Executive, South Central         Austin%2C+TX
# 513                                     Java Developer         Austin%2C+TX
#
#      Salary Index                                            Summary
# 0             1.0  Data skills (SQL, Hive, Pig). Applying machine...
# 1             1.0  Have a pulse on partner industry to identify t...
# 2             1.0  Mentor a team of data scientists and ML engine...
# 3             1.0  Explores existing data for insights and recomm...
# 4             1.0  Junior Research Scientist. This position is re...
# 5             1.0  The Team You can’t wait to join a team of data...
# 6             1.0  Demonstrated experience analyzing multidimensi...
# 7             1.0  As a Lead Data Scientist, you will head up a 2...
# 8             1.0  This person will recruit, build and lead a tea...
# 9             1.0  Teams included Data Services(including data en...
# 10            1.0  Manager, Data Science. Top technology firm in ...
# 11            1.0  Experience analyzing data. Rocket Fuel technol...
# 12            1.0  $150, 000 base salary, commensurate with exper...
# 13            1.0  At least 3 years postdoctoral experience, and ...
# 14            1.0  The ideal candidate is a hands-on platform bui...
# 15            1.0  Occasionally lift or move objects up to 30 lbs...
# 16            1.0  Based on analysis of data, make recommendation...
# 17            1.0  Position Title: CloudScaling Engineer Position...
# 18            1.0  Resulting in a sales closure) we are willing t...
# 19            1.0  At the root of Aspera’s success lies our innov...
# 20            1.0  Work with the team of engineers and data scien...
# 21            1.0  Postuler à ce poste Attachez une pièce jointe,...
# 22            1.0  With Docker, IT organizations shrink applicati...
# 23            1.0  Mentor a team of data scientists and ML engine...
# 24            1.0  Our team is made up of world class, award-winn...
# 25            1.0  Postuler à ce poste Attachez une pièce jointe,...
# 26            1.0  With Docker, IT organizations shrink applicati...
# 27            1.0  With Docker, IT organizations shrink applicati...
# 28            1.0  Software Engineer, Data science, data scientis...
# 29            1.0  You will work with third-party API’ s to integ...
# ..            ...                                                ...
# 484           1.0  With Docker, IT organizations shrink applicati...
# 485           1.0  Design, optimize and operate data models used ...
# 486           1.0  Within 30 days after entering Texas as a new r...
# 487           1.0  Work with data scientists and other technical ...
# 488           1.0  With Docker, IT organizations shrink applicati...
# 489           1.0  Design, optimize and operate data models used ...
# 490           1.0  Within 30 days after entering Texas as a new r...
# 491           1.0  Work with data scientists and other technical ...
# 492           1.0  With Docker, IT organizations shrink applicati...
# 493           1.0  Design, optimize and operate data models used ...
# 494           1.0  Within 30 days after entering Texas as a new r...
# 495           1.0  Work with data scientists and other technical ...
# 496           1.0  With Docker, IT organizations shrink applicati...
# 497           1.0  Design, optimize and operate data models used ...
# 498           1.0  Within 30 days after entering Texas as a new r...
# 499           1.0  Work with data scientists and other technical ...
# 500           1.0  With Docker, IT organizations shrink applicati...
# 501           1.0  Design, optimize and operate data models used ...
# 502           1.0  Within 30 days after entering Texas as a new r...
# 503           1.0  Work with data scientists and other technical ...
# 504           1.0  With Docker, IT organizations shrink applicati...
# 505           1.0  Design, optimize and operate data models used ...
# 506           1.0  Within 30 days after entering Texas as a new r...
# 507           1.0  Work with data scientists and other technical ...
# 508           1.0  With Docker, IT organizations shrink applicati...
# 509           1.0  Design, optimize and operate data models used ...
# 510           1.0  Within 30 days after entering Texas as a new r...
# 511           1.0  Work with data scientists and other technical ...
# 512           1.0  With Docker, IT organizations shrink applicati...
# 513           1.0  Design, optimize and operate data models used ...
#
# [514 rows x 5 columns]

# %% [markdown]
# #### Learning about the data sets

# %%
categorical = df.dtypes[df.dtypes == "object"].index
df[categorical].describe()
# Out:
#        Company Name         Job Title      Location  \
# count           820               820           820
# unique          502               621             5
# top          Natera  Research Analyst  Boston%2C+MA
# freq             24                40           180
#
#                                                   Summary
# count                                                 820
# unique                                                720
# top     The Lab Technician I reports to a Supervisor, ...
# freq                                                   14

# %%
categorical = df2.dtypes[df.dtypes == "object"].index
df2[categorical].describe()
# Out:
#        Company Name           Job Title      Location  \
# count           514                 514           514
# unique           77                 167             5
# top          Biogen  Research Scientist  Boston%2C+MA
# freq             59                  20           164
#
#                                                   Summary
# count                                                 514
# unique                                                142
# top     Physician Affiliate Group of New York (PAGNY) ...
# freq                                                   41

# %% [markdown]
# #### Merging the two dataframes together

# %%
mergedDF = [df, df2]
df4 = pd.concat(mergedDF)
df4 = df4.reset_index()
del df4['index']

# %% [markdown]
# ### Save your results as a CSV

# %%
df4.to_csv("datascience.csv", encoding='utf-8')

# %% [markdown]
# ## Predicting salaries using Logistic Regression

# %% [markdown]
# #### Load in the the data of scraped salaries, create dummy variables for the cities and perform a train test split on the data.

# %%
df4 = pd.read_csv("../Assets/Project4/datascience.csv")
df5=df4[['Location','Salary Index']]
dummies = pd.get_dummies( df5["Location"], prefix = "Location" )
dummies['Intercept']=1
dummies.columns=['Austin','Boston', 'Chicago','New York','San Francisco','Intercept']
y=df5['Salary Index']
X=dummies[['Boston','Chicago','New York','San Francisco','Intercept']]
# split data randomly into datasets, 70% train, 30% test using test train split
X_train, X_test, y_train, y_test = train_test_split( X, y, test_size=0.30, random_state=30)

# %% [markdown]
# #### Create a Logistic Regression model to predict High/Low salary using statsmodel. Start by ONLY using the location as a feature. Display the coefficients and write a short summary of what they mean.

# %%
logit = sm.Logit(y_train, X_train)
result = logit.fit()
result.summary()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.644395
#          Iterations 5
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:           Salary Index   No. Observations:                  933
# Model:                          Logit   Df Residuals:                      928
# Method:                           MLE   Df Model:                            4
# Date:                Thu, 30 Jun 2016   Pseudo R-squ.:                 0.03073
# Time:                        18:03:02   Log-Likelihood:                -601.22
# converged:                       True   LL-Null:                       -620.28
#                                         LLR p-value:                 1.057e-07
# =================================================================================
#                     coef    std err          z      P>|z|      [95.0% Conf. Int.]
# ---------------------------------------------------------------------------------
# Boston            0.0009      0.217      0.004      0.997        -0.424     0.426
# Chicago          -0.6417      0.236     -2.716      0.007        -1.105    -0.179
# New York         -0.1917      0.221     -0.868      0.385        -0.624     0.241
# San Francisco    -1.2042      0.262     -4.603      0.000        -1.717    -0.691
# Intercept        -0.1355      0.174     -0.780      0.436        -0.476     0.205
# =================================================================================
# """

# %%
np.exp(result.params) #convert your parameters to odds ratio
# Out:
# Boston           1.000889
# Chicago          0.526405
# New York         0.825581
# San Francisco    0.299923
# Intercept        0.873239
# dtype: float64

# %%
conf=result.conf_int()
conf['OR']=result.params
conf.columns=['2.5%','97.5%','OR']
np.exp(conf)#convert to odds ratio
# Out:
#                    2.5%     97.5%        OR
# Boston         0.654124  1.531481  1.000889
# Chicago        0.331291  0.836431  0.526405
# New York       0.535650  1.272444  0.825581
# San Francisco  0.179600  0.500858  0.299923
# Intercept      0.621122  1.227692  0.873239

# %%
dfTest=X_test
dfTest['predictedSalary'] = result.predict( dfTest )
dfTest["actualSalary"] = y_test
# Out:
# /anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app
# /anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()

# %% [markdown]
# #### This loop helped me determine the best cutoff point for my model

# %%
for i in range(45,56,1):
    cutoff=i/100.0
    xyz = dfTest["predictedSalary"]
    dfTest["Predicted"] = [0 if i < cutoff else 1 for i in xyz]
    A= confusion_matrix(dfTest['actualSalary'],dfTest['Predicted'])
    Accuracy = (A[0,0]+ A[1,1])/float(len(dfTest["Predicted"]))
    print "My cutoff is: %r and ACC: %r"%(cutoff,Accuracy)
# Out:
# /anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# My cutoff is: 0.45 and ACC: 0.55361596009975067
# My cutoff is: 0.46 and ACC: 0.55361596009975067
# My cutoff is: 0.47 and ACC: 0.6059850374064838
# My cutoff is: 0.48 and ACC: 0.6059850374064838
# My cutoff is: 0.49 and ACC: 0.6059850374064838
# My cutoff is: 0.5 and ACC: 0.6059850374064838
# My cutoff is: 0.51 and ACC: 0.6059850374064838
# My cutoff is: 0.52 and ACC: 0.6059850374064838
# My cutoff is: 0.53 and ACC: 0.6059850374064838
# My cutoff is: 0.54 and ACC: 0.6059850374064838
# My cutoff is: 0.55 and ACC: 0.6059850374064838

# %% [markdown]
# #### Using the information from the previous step, a cutoff of 0.46 is used.

# %%
cutoff=0.46
xyz = dfTest["predictedSalary"]
dfTest["Predicted"] = [0 if i < cutoff else 1 for i in xyz]
print pd.crosstab(dfTest['actualSalary'], dfTest['Predicted'], rownames=['Actual'])
# Out:
# Predicted    0   1
# Actual
# 0.0        151  92
# 1.0         87  71
# /anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()

# %%
Accuracy = (222)/float(len(dfTest["Predicted"]))
Accuracy
# Out:
# 0.5536159600997507

# %% [markdown]
# The accuracy of the model is around 55% which is a very low number to work with. I believe that there is a lot of Bias in the data collected. I belive that a more reliable source of data should be found. I will continue to use this data set to see if it is possible to increase the accuracy of the model using other tools available.

# %% [markdown]
# #### Rebuild this model with scikit-learn.
# - You can either create the dummy features manually or use the `dmatrix` function from `patsy`
# - Remember to scale the feature variables as well!

# %%
X_train, X_test, y_train, y_test = train_test_split( X, y, test_size=0.30, random_state=30)
model2 = LogisticRegression()
model2.fit(X_train, y_train)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False)

# %%
dfTest2=X_test
dfTest2['predictedSalary'] = model2.predict(X_test)
dfTest2["actualSalary"] = y_test
# Out:
# /anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app
# /anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()

# %%
print metrics.accuracy_score(y_test, dfTest2['predictedSalary'])
print pd.crosstab(y_test, dfTest2['predictedSalary'], rownames=['Actual'])
# Out:
# 0.605985037406
# predictedSalary  0.0
# Actual
# 0.0              243
# 1.0              158

# %% [markdown]
# Clearly using sklearn logistic regression does improve my accuracy but the model is wrong as it is just predicting everything to be low salary.

# %% [markdown]
# #### Use cross-validation in scikit-learn to evaluate the model above.

# %%
scores = cross_val_score(LogisticRegression(), X, y, scoring='accuracy', cv=10)
print scores
print scores.mean()
# Out:
# [ 0.6119403   0.6119403   0.6119403   0.17910448  0.61654135  0.61654135
#   0.61654135  0.38345865  0.37593985  0.61654135]
# 0.524048928291

# %% [markdown]
# #### Compare L1 and L2 regularization for this logistic regression model. What effect does this have on the coefficients learned?

# %%
X_train, X_test, y_train, y_test = train_test_split( X, y, test_size=0.30, random_state=30)
L1Model= LogisticRegression(penalty='l1')
L1Model.fit(X_train, y_train)
dfTest3=X_test
dfTest3['predictedSalary'] = L1Model.predict(X_test)
dfTest3["actualSalary"] = y_test
print metrics.accuracy_score(y_test, dfTest3['predictedSalary'])
print pd.crosstab(y_test, dfTest3['predictedSalary'], rownames=['Actual'])
# Out:
# 0.605985037406
# predictedSalary  0.0
# Actual
# 0.0              243
# 1.0              158
# /anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
X_train, X_test, y_train, y_test = train_test_split( X, y, test_size=0.30, random_state=30)
L2Model= LogisticRegression(penalty='l2')
L2Model.fit(X_train, y_train)
dfTest4=X_test
dfTest4['predictedSalary'] = L2Model.predict(X_test)
dfTest4["actualSalary"] = y_test
print metrics.accuracy_score(y_test, dfTest4['predictedSalary'])
print pd.crosstab(y_test, dfTest4['predictedSalary'], rownames=['Actual'])
# Out:
# 0.605985037406
# predictedSalary  0.0
# Actual
# 0.0              243
# 1.0              158
# /anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %% [markdown]
# ### BONUS

# %% [markdown]
# #### Bonus: Use Count Vectorizer from scikit-learn to create features from the text summaries.
# - Examine using count or binary features in the model
# - Re-evaluate the logistic regression model using these. Does this improve the model performance?
# - What text features are the most valuable?

# %%
## YOUR CODE HERE

# %%
## YOUR CODE HERE

# %% [markdown]
# #### Re-test L1 and L2 regularization. You can use LogisticRegressionCV to find the optimal reguarlization parameters.
# - Re-test what text features are most valuable.
# - How do L1 and L2 change the coefficients?

# %%
## YOUR CODE HERE
